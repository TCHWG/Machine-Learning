# %%
import pandas as pd

df = pd.read_csv('output/v5/dataset_features.csv')
df.head(100)
# Out:
#                                       midi_file   avg_ioi   std_ioi  \
# 0   sample_0000_mistouch_with_reorientation.mid  0.245570  0.368244
# 1            sample_0001_mistouch_with_none.mid  0.234295  0.353906
# 2        sample_0002_mistouch_with_rollback.mid  0.228760  0.411276
# 3   sample_0003_mistouch_with_reorientation.mid  0.244851  0.383854
# 4            sample_0004_mistouch_with_none.mid  0.234295  0.353906
# ..                                          ...       ...       ...
# 95         sample_0095_join_notes_with_none.mid  0.326433  0.380037
# 96     sample_0096_join_notes_with_rollback.mid  0.319259  0.428431
# 97     sample_0097_join_notes_with_rollback.mid  0.319259  0.455161
# 98                     sample_0098_no_error.mid  0.326074  0.381399
# 99                     sample_0099_no_error.mid  0.326446  0.381411
#
#     avg_velocity  velocity_std  velocity_range  pitch_range  \
# 0      72.256000     10.011916              44           30
# ...

# %%
df = pd.read_csv('output/v6/dataset_features.csv')
df
# Out:
#                       midi_file   avg_ioi   std_ioi  avg_velocity  \
# 0   sample_0000_multi_error.mid  0.184884  0.330546     67.367089
# 1   sample_0001_multi_error.mid  0.234295  0.353906     72.256000
# 2   sample_0002_multi_error.mid  0.326433  0.395950     76.844444
# 3   sample_0003_multi_error.mid  0.326433  0.380037     76.844444
# 4   sample_0004_multi_error.mid  0.326433  0.381477     76.844444
# ..                          ...       ...       ...           ...
# 95  sample_0095_multi_error.mid  0.326433  0.417201     76.844444
# 96  sample_0096_multi_error.mid  0.234295  0.353906     60.384000
# 97  sample_0097_multi_error.mid  0.326433  0.380037     63.500000
# 98  sample_0098_multi_error.mid  0.236487  0.353318     72.387097
# 99  sample_0099_multi_error.mid  0.235540  0.368705     72.467742
#
#     velocity_std  velocity_range  pitch_range  avg_pitch_interval  \
# 0      13.289548              53           30            6.624204
# ...

# %%
df = pd.read_csv('output/v6/dataset_features.csv')
df
# Out:
#                       midi_file   avg_ioi   std_ioi  avg_velocity  \
# 0   sample_0000_multi_error.mid  0.184884  0.330546     67.367089
# 1   sample_0001_multi_error.mid  0.234295  0.353906     72.256000
# 2   sample_0002_multi_error.mid  0.326433  0.395950     76.844444
# 3   sample_0003_multi_error.mid  0.326433  0.380037     76.844444
# 4   sample_0004_multi_error.mid  0.326433  0.381477     76.844444
# ..                          ...       ...       ...           ...
# 95  sample_0095_multi_error.mid  0.326433  0.417201     76.844444
# 96  sample_0096_multi_error.mid  0.234295  0.353906     60.384000
# 97  sample_0097_multi_error.mid  0.326433  0.380037     63.500000
# 98  sample_0098_multi_error.mid  0.236487  0.353318     72.387097
# 99  sample_0099_multi_error.mid  0.235540  0.368705     72.467742
#
#     velocity_std  velocity_range  pitch_range  avg_pitch_interval  \
# 0      13.289548              53           30            6.624204
# ...

# %%
df = pd.read_csv('output/v6/mistake_details.csv')
df
# Out:
#                        midi_file  timestamp             error_type
# 0    sample_0000_multi_error.mid   3.789462               mistouch
# 1    sample_0000_multi_error.mid   2.523028   incorrect_asynchrony
# 2    sample_0000_multi_error.mid  11.398504       anticipated_note
# 3    sample_0000_multi_error.mid   2.523028               mistouch
# 4    sample_0001_multi_error.mid   1.263154             join_notes
# ..                           ...        ...                    ...
# 329  sample_0099_multi_error.mid   6.947347             join_notes
# 330  sample_0099_multi_error.mid   1.265078   incorrect_asynchrony
# 331  sample_0099_multi_error.mid   8.816552       anticipated_note
# 332  sample_0099_multi_error.mid  16.429034  substitution_harmonic
# 333  sample_0099_multi_error.mid  16.391229               mistouch
#
# [334 rows x 3 columns]

# %%
df = pd.read_csv('output/v7/dataset_features.csv')
df
# Out:
#                           midi_file   avg_ioi   std_ioi  avg_velocity  \
# 0          sample_0000_NO_ERROR.mid  0.326433  0.380037     76.844444
# 1   sample_0001_MULTIPLE_ERRORS.mid  0.326433  0.380554     76.844444
# 2   sample_0002_MULTIPLE_ERRORS.mid  0.326433  0.380037     76.133333
# 3          sample_0003_NO_ERROR.mid  0.326433  0.380037     76.844444
# 4   sample_0004_MULTIPLE_ERRORS.mid  0.326433  0.380947     76.844444
# 5   sample_0005_MULTIPLE_ERRORS.mid  0.326433  0.380741     76.088889
# 6          sample_0006_NO_ERROR.mid  0.326433  0.380037     76.844444
# 7   sample_0007_MULTIPLE_ERRORS.mid  0.326433  0.380232     75.755556
# 8   sample_0008_MULTIPLE_ERRORS.mid  0.326433  0.380985     75.844444
# 9   sample_0009_MULTIPLE_ERRORS.mid  0.326433  0.382001     76.677778
# 10  sample_0010_MULTIPLE_ERRORS.mid  0.326433  0.380037     76.166667
# 11  sample_0011_MULTIPLE_ERRORS.mid  0.326433  0.380234     76.133333
# ...

# %%
df = pd.read_csv('output/v8/dataset_features.csv')
df
# Out:
#                                      midi_file   avg_ioi   std_ioi   max_ioi  \
# 0   sample_0000_forward_backward_insertion.mid  0.271519  0.363624  1.263154
# 1   sample_0001_forward_backward_insertion.mid  0.276691  0.370848  1.263154
# 2   sample_0002_forward_backward_insertion.mid  0.284829  0.368906  1.263154
# 3   sample_0003_forward_backward_insertion.mid  0.293460  0.363315  1.263154
# 4   sample_0004_forward_backward_insertion.mid  0.274081  0.366792  1.263154
# ..                                         ...       ...       ...       ...
# 95                    sample_0095_no_error.mid  0.326299  0.379760  1.292014
# 96                    sample_0096_no_error.mid  0.326334  0.378724  1.283917
# 97                    sample_0097_no_error.mid  0.326632  0.379538  1.287275
# 98                    sample_0098_no_error.mid  0.326597  0.381142  1.277745
# 99                    sample_0099_no_error.mid  0.326293  0.379373  1.292584
#
# ...

# %%
import json
df = pd.read_csv("dataset_features.csv")

df['mistake_details'] = df['mistake_details'].apply(json.loads)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Load the CSV
#       2 import json
# ----> 3 df = pd.read_csv("dataset_features.csv")
#       5 # Parse JSON column
#       6 df['mistake_details'] = df['mistake_details'].apply(json.loads)
#
# ...
